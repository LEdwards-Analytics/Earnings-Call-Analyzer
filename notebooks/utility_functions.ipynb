# %%
# Import standard libraries
import sys
import os
from pathlib import Path

# Enable auto-reloading of modules
# %load_ext autoreload
# %autoreload 2

# Import from your package
from earnings_call_analyzer.transcript_collection import (
    # Constants
    BASE_URL,
    USER_AGENTS,

    # Web scraping utilities
    get_random_user_agent,
    get_scraping_headers,
    wait_with_jitter,

    # Transcript fetching from different sources
    get_company_ir_transcript,
    get_seeking_alpha_transcript,
    get_yahoo_finance_transcript,

    # Processing functions
    process_company,
    update_metadata
)

# Test a simple function
print(get_random_user_agent())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.82 Safari/537.36
